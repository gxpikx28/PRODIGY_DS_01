# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\sun11\\Downloads\\archive (3)\\matches.csv")
f=pd.DataFrame(df)
plt.hist(f['season'],color='lightgreen',edgecolor='blue',width=0.9)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\sun11\\Downloads\\archive (3)\\matches.csv")
f=pd.DataFrame(df)
d=f.head()
plt.bar(f['id'],f['win_by_runs'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\sun11\\Downloads\\archive (3)\\matches.csv")
f=pd.DataFrame(df)
d=f.head(10)
plt.bar(d['id'],d['win_by_runs'])
plt.show()
